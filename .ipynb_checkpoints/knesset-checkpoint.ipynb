# %%
# imports 
import pandas
import numpy
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import IncrementalPCA

from keras.models import Model, Sequential
from keras.layers import Dense, Dropout

# %%
join_cols = ['שם ישוב', 'מספר קלפי']
drop_cols =  ['סמל ישוב', 'בזב', 'מצביעים', 'פסולים']
total_col = 'כשרים'

def read_and_processes(file, suffix):
     # read the file
    df = pandas.read_csv(file, encoding = 'windows-1255')
    
    # basic processing 
    df.columns = df.columns.map(lambda col: col.strip()) # strip whitespaces in columns
    df = df.drop(drop_cols, axis=1) # remove unnecessary columns
    df = df[(df[total_col] > 0)] # removing ballot with n  valid votes 
    
    # norming to percentage (% of valid votes)
    total_col_idx = df.columns.get_loc(total_col)
    df = df.apply(lambda row: [row[idx]/row[total_col_idx] if idx > total_col_idx else row[idx] for idx in range(len(row))], axis=1) 
    df = df.drop([total_col], axis=1)
    
    # applying suffix
    df.columns = df.columns.map(lambda x: x if x in join_cols else str(x) + suffix) 
    return df

# %%
# reading knesset 20 votes from https://www.votes20-media.gov.il/files/expb.csv
k20 = read_and_processes('knesset20.csv', '_20')
print ('Knesset 20: number of ballot boxes =', len(k20))

# reading knesset 21 votes from https://media21.bechirot.gov.il/files/expb.csv
k21 = read_and_processes('knesset21.csv', '_21')
print ('Knesset 21: number of ballot boxes =', len(k21))
# Out:
# Knesset 20: number of ballot boxes = 10412
# Knesset 21: number of ballot boxes = 10765

# %%
k20_21_merged = pandas.merge(k20, k21, left_on=join_cols, right_on=join_cols)
print ('Knesset 20/21: number of matched ballot boxes =', len(k20_21_merged))

k20_features = [col for col in k20_21_merged.columns if col.endswith('_20')]
k20_len = len(k20_features)

k21_features = [col for col in k20_21_merged.columns if col.endswith('_21')]
k21_len = len(k21_features)

print ('Knesset 20: number of parties =', k20_len)
print ('Knesset 21: number of parties =', k21_len)

k20_data = k20_21_merged[k20_features]
k21_data = k20_21_merged[k21_features]
# Out:
# Knesset 20/21: number of matched ballot boxes = 8565
# Knesset 20: number of parties = 26
# Knesset 21: number of parties = 43

# %%
# modeling 
numpy.random.seed(9876) # for reproducibility

# hidden dims = mean of input and output layers 
hidden_dims = int((k20_len + k21_len)/2) 
model = Sequential()

model.add(Dense(input_dim=k20_len, units=hidden_dims, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=hidden_dims, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=hidden_dims, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=hidden_dims, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=k21_len, activation='relu'))

model.compile(loss='mse', optimizer='rmsprop', metrics=['accuracy'])
# model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
model.fit(k20_data, k21_data, epochs=100, validation_split=0.8)
# Out:
# Train on 856 samples, validate on 7709 samples
# Epoch 1/100
# 856/856 [==============================] - 1s 1ms/step - loss: 0.0051 - acc: 0.4451 - val_loss: 0.0032 - val_acc: 0.4800
# Epoch 2/100
# 856/856 [==============================] - 0s 304us/step - loss: 0.0033 - acc: 0.6600 - val_loss: 0.0027 - val_acc: 0.4841
# Epoch 3/100
# 856/856 [==============================] - 0s 187us/step - loss: 0.0028 - acc: 0.6893 - val_loss: 0.0023 - val_acc: 0.5673
# Epoch 4/100
# 856/856 [==============================] - 0s 185us/step - loss: 0.0026 - acc: 0.6974 - val_loss: 0.0020 - val_acc: 0.6460
# Epoch 5/100
# 856/856 [==============================] - 0s 296us/step - loss: 0.0023 - acc: 0.7395 - val_loss: 0.0017 - val_acc: 0.7506
# Epoch 6/100
# 856/856 [==============================] - 0s 301us/step - loss: 0.0020 - acc: 0.7710 - val_loss: 0.0014 - val_acc: 0.7984
# Epoch 7/100
# 856/856 [==============================] - 0s 227us/step - loss: 0.0019 - acc: 0.7710 - val_loss: 0.0012 - val_acc: 0.8142
# Epoch 8/100
# 856/856 [==============================] - 0s 217us/step - loss: 0.0017 - acc: 0.7991 - val_loss: 0.0011 - val_acc: 0.8257
# Epoch 9/100
# 856/856 [==============================] - 0s 235us/step - loss: 0.0017 - acc: 0.8072 - val_loss: 0.0011 - val_acc: 0.8305
# Epoch 10/100
# 856/856 [==============================] - 0s 261us/step - loss: 0.0016 - acc: 0.7921 - val_loss: 0.0010 - val_acc: 0.8333
# Epoch 11/100
# 856/856 [==============================] - 0s 217us/step - loss: 0.0015 - acc: 0.8014 - val_loss: 9.8124e-04 - val_acc: 0.8353
# Epoch 12/100
# 856/856 [==============================] - 0s 271us/step - loss: 0.0016 - acc: 0.7909 - val_loss: 9.3181e-04 - val_acc: 0.8366
# Epoch 13/100
# 856/856 [==============================] - 0s 322us/step - loss: 0.0015 - acc: 0.8131 - val_loss: 9.0880e-04 - val_acc: 0.8388
# Epoch 14/100
# 856/856 [==============================] - 0s 265us/step - loss: 0.0014 - acc: 0.8107 - val_loss: 9.1256e-04 - val_acc: 0.8402
# Epoch 15/100
# 856/856 [==============================] - 0s 252us/step - loss: 0.0013 - acc: 0.8084 - val_loss: 8.7895e-04 - val_acc: 0.8394
# Epoch 16/100
# 856/856 [==============================] - 0s 200us/step - loss: 0.0014 - acc: 0.8224 - val_loss: 8.8750e-04 - val_acc: 0.8310
# Epoch 17/100
# 856/856 [==============================] - 0s 242us/step - loss: 0.0013 - acc: 0.8341 - val_loss: 8.5314e-04 - val_acc: 0.8380
# Epoch 18/100
# 856/856 [==============================] - 0s 257us/step - loss: 0.0013 - acc: 0.8236 - val_loss: 8.5548e-04 - val_acc: 0.8449
# Epoch 19/100
# 856/856 [==============================] - 0s 261us/step - loss: 0.0013 - acc: 0.8224 - val_loss: 8.5965e-04 - val_acc: 0.8323
# Epoch 20/100
# 856/856 [==============================] - 0s 311us/step - loss: 0.0012 - acc: 0.8271 - val_loss: 7.8617e-04 - val_acc: 0.8513
# Epoch 21/100
# 856/856 [==============================] - 0s 275us/step - loss: 0.0013 - acc: 0.8248 - val_loss: 8.2734e-04 - val_acc: 0.8380
# Epoch 22/100
# 856/856 [==============================] - 0s 299us/step - loss: 0.0013 - acc: 0.8388 - val_loss: 7.9282e-04 - val_acc: 0.8504
# Epoch 23/100
# 856/856 [==============================] - 0s 281us/step - loss: 0.0012 - acc: 0.8318 - val_loss: 7.8787e-04 - val_acc: 0.8516
# Epoch 24/100
# 856/856 [==============================] - 0s 269us/step - loss: 0.0012 - acc: 0.8411 - val_loss: 7.6161e-04 - val_acc: 0.8589
# Epoch 25/100
# 856/856 [==============================] - 0s 288us/step - loss: 0.0012 - acc: 0.8376 - val_loss: 7.9881e-04 - val_acc: 0.8533
# Epoch 26/100
# 856/856 [==============================] - 0s 312us/step - loss: 0.0012 - acc: 0.8458 - val_loss: 8.0851e-04 - val_acc: 0.8498
# Epoch 27/100
# 856/856 [==============================] - 0s 265us/step - loss: 0.0011 - acc: 0.8481 - val_loss: 7.9206e-04 - val_acc: 0.8532
# Epoch 28/100
# 856/856 [==============================] - 0s 276us/step - loss: 0.0011 - acc: 0.8353 - val_loss: 8.0214e-04 - val_acc: 0.8390
# Epoch 29/100
# 856/856 [==============================] - 0s 272us/step - loss: 0.0011 - acc: 0.8481 - val_loss: 8.0252e-04 - val_acc: 0.8437
# Epoch 30/100
# 856/856 [==============================] - 0s 308us/step - loss: 0.0011 - acc: 0.8481 - val_loss: 8.0703e-04 - val_acc: 0.8498
# Epoch 31/100
# 856/856 [==============================] - 0s 219us/step - loss: 0.0011 - acc: 0.8458 - val_loss: 8.0435e-04 - val_acc: 0.8571
# Epoch 32/100
# 856/856 [==============================] - 0s 214us/step - loss: 0.0012 - acc: 0.8400 - val_loss: 8.0202e-04 - val_acc: 0.8594
# Epoch 33/100
# 856/856 [==============================] - 0s 320us/step - loss: 0.0011 - acc: 0.8551 - val_loss: 7.6382e-04 - val_acc: 0.8576
# Epoch 34/100
# 856/856 [==============================] - 0s 186us/step - loss: 0.0011 - acc: 0.8400 - val_loss: 7.8305e-04 - val_acc: 0.8504
# Epoch 35/100
# 856/856 [==============================] - 0s 201us/step - loss: 0.0011 - acc: 0.8400 - val_loss: 7.7802e-04 - val_acc: 0.8600
# Epoch 36/100
# 856/856 [==============================] - 0s 174us/step - loss: 0.0011 - acc: 0.8540 - val_loss: 7.5557e-04 - val_acc: 0.8586
# Epoch 37/100
# 856/856 [==============================] - 0s 183us/step - loss: 0.0011 - acc: 0.8551 - val_loss: 7.5782e-04 - val_acc: 0.8519
# Epoch 38/100
# 856/856 [==============================] - 0s 201us/step - loss: 0.0011 - acc: 0.8528 - val_loss: 7.7335e-04 - val_acc: 0.8578
# Epoch 39/100
# 856/856 [==============================] - 0s 235us/step - loss: 9.8516e-04 - acc: 0.8516 - val_loss: 7.7654e-04 - val_acc: 0.8547
# Epoch 40/100
# 856/856 [==============================] - 0s 226us/step - loss: 0.0010 - acc: 0.8598 - val_loss: 7.7295e-04 - val_acc: 0.8591
# Epoch 41/100
# 856/856 [==============================] - 0s 225us/step - loss: 0.0010 - acc: 0.8481 - val_loss: 7.9474e-04 - val_acc: 0.8551
# Epoch 42/100
# 856/856 [==============================] - 0s 167us/step - loss: 9.9519e-04 - acc: 0.8575 - val_loss: 7.8054e-04 - val_acc: 0.8616
# Epoch 43/100
# 856/856 [==============================] - 0s 285us/step - loss: 0.0010 - acc: 0.8621 - val_loss: 7.6144e-04 - val_acc: 0.8617
# Epoch 44/100
# 856/856 [==============================] - 0s 287us/step - loss: 0.0010 - acc: 0.8715 - val_loss: 7.9460e-04 - val_acc: 0.8463
# Epoch 45/100
# 856/856 [==============================] - 0s 278us/step - loss: 9.9837e-04 - acc: 0.8516 - val_loss: 7.8072e-04 - val_acc: 0.8598
# Epoch 46/100
# 856/856 [==============================] - 0s 197us/step - loss: 9.6265e-04 - acc: 0.8540 - val_loss: 7.7443e-04 - val_acc: 0.8521
# Epoch 47/100
# 856/856 [==============================] - 0s 242us/step - loss: 0.0010 - acc: 0.8621 - val_loss: 7.9773e-04 - val_acc: 0.8493
# Epoch 48/100
# 856/856 [==============================] - 0s 264us/step - loss: 9.2774e-04 - acc: 0.8633 - val_loss: 7.8690e-04 - val_acc: 0.8546
# Epoch 49/100
# 856/856 [==============================] - 0s 255us/step - loss: 0.0010 - acc: 0.8610 - val_loss: 7.7286e-04 - val_acc: 0.8537
# Epoch 50/100
# 856/856 [==============================] - 0s 185us/step - loss: 9.4785e-04 - acc: 0.8551 - val_loss: 8.0661e-04 - val_acc: 0.8555
# Epoch 51/100
# 856/856 [==============================] - 0s 192us/step - loss: 9.6921e-04 - acc: 0.8680 - val_loss: 7.5423e-04 - val_acc: 0.8542
# Epoch 52/100
# 856/856 [==============================] - 0s 177us/step - loss: 9.2766e-04 - acc: 0.8680 - val_loss: 8.1363e-04 - val_acc: 0.8594
# Epoch 53/100
# 856/856 [==============================] - 0s 193us/step - loss: 9.5320e-04 - acc: 0.8645 - val_loss: 7.8246e-04 - val_acc: 0.8595
# Epoch 54/100
# 856/856 [==============================] - 0s 215us/step - loss: 9.2977e-04 - acc: 0.8505 - val_loss: 8.3061e-04 - val_acc: 0.8462
# Epoch 55/100
# 856/856 [==============================] - 0s 192us/step - loss: 9.5511e-04 - acc: 0.8645 - val_loss: 7.3709e-04 - val_acc: 0.8537
# Epoch 56/100
# 856/856 [==============================] - 0s 189us/step - loss: 9.2409e-04 - acc: 0.8715 - val_loss: 8.0858e-04 - val_acc: 0.8546
# Epoch 57/100
# 856/856 [==============================] - 0s 196us/step - loss: 9.6488e-04 - acc: 0.8551 - val_loss: 7.5954e-04 - val_acc: 0.8580
# Epoch 58/100
# 856/856 [==============================] - 0s 268us/step - loss: 9.4143e-04 - acc: 0.8563 - val_loss: 7.4948e-04 - val_acc: 0.8581
# Epoch 59/100
# 856/856 [==============================] - 0s 363us/step - loss: 8.8602e-04 - acc: 0.8738 - val_loss: 7.4117e-04 - val_acc: 0.8535
# Epoch 60/100
# 856/856 [==============================] - 0s 437us/step - loss: 8.7151e-04 - acc: 0.8668 - val_loss: 8.4276e-04 - val_acc: 0.8455
# Epoch 61/100
# 856/856 [==============================] - 0s 330us/step - loss: 9.4596e-04 - acc: 0.8575 - val_loss: 8.3292e-04 - val_acc: 0.8551
# Epoch 62/100
# 856/856 [==============================] - 0s 323us/step - loss: 8.9008e-04 - acc: 0.8657 - val_loss: 7.7717e-04 - val_acc: 0.8526
# Epoch 63/100
# 856/856 [==============================] - 0s 319us/step - loss: 9.0419e-04 - acc: 0.8540 - val_loss: 7.8781e-04 - val_acc: 0.8468
# Epoch 64/100
# 856/856 [==============================] - 0s 223us/step - loss: 8.8117e-04 - acc: 0.8633 - val_loss: 8.1562e-04 - val_acc: 0.8596
# Epoch 65/100
# 856/856 [==============================] - 0s 218us/step - loss: 8.8963e-04 - acc: 0.8820 - val_loss: 8.2563e-04 - val_acc: 0.8569
# Epoch 66/100
# 856/856 [==============================] - 0s 183us/step - loss: 8.6704e-04 - acc: 0.8832 - val_loss: 7.6880e-04 - val_acc: 0.8554
# Epoch 67/100
# 856/856 [==============================] - 0s 224us/step - loss: 8.7017e-04 - acc: 0.8680 - val_loss: 8.2385e-04 - val_acc: 0.8460
# Epoch 68/100
# 856/856 [==============================] - 0s 230us/step - loss: 8.7080e-04 - acc: 0.8703 - val_loss: 7.8201e-04 - val_acc: 0.8469
# Epoch 69/100
# 856/856 [==============================] - 0s 210us/step - loss: 8.4709e-04 - acc: 0.8621 - val_loss: 8.6549e-04 - val_acc: 0.8574
# Epoch 70/100
# 856/856 [==============================] - 0s 259us/step - loss: 9.1882e-04 - acc: 0.8610 - val_loss: 7.7957e-04 - val_acc: 0.8555
# Epoch 71/100
# 856/856 [==============================] - 0s 301us/step - loss: 8.2799e-04 - acc: 0.8879 - val_loss: 7.8964e-04 - val_acc: 0.8459
# Epoch 72/100
# 856/856 [==============================] - 0s 314us/step - loss: 8.7082e-04 - acc: 0.8715 - val_loss: 8.2023e-04 - val_acc: 0.8560
# Epoch 73/100
# 856/856 [==============================] - 0s 280us/step - loss: 8.3865e-04 - acc: 0.8843 - val_loss: 7.7530e-04 - val_acc: 0.8462
# Epoch 74/100
# 856/856 [==============================] - 0s 281us/step - loss: 8.7033e-04 - acc: 0.8645 - val_loss: 8.1276e-04 - val_acc: 0.8449
# Epoch 75/100
# 856/856 [==============================] - 0s 370us/step - loss: 8.3273e-04 - acc: 0.8598 - val_loss: 7.8854e-04 - val_acc: 0.8556
# Epoch 76/100
# 856/856 [==============================] - 0s 372us/step - loss: 8.4717e-04 - acc: 0.8715 - val_loss: 8.0005e-04 - val_acc: 0.8538
# Epoch 77/100
# 856/856 [==============================] - 0s 242us/step - loss: 7.8593e-04 - acc: 0.8703 - val_loss: 8.3968e-04 - val_acc: 0.8456
# Epoch 78/100
# 856/856 [==============================] - 0s 177us/step - loss: 8.1243e-04 - acc: 0.8785 - val_loss: 8.3341e-04 - val_acc: 0.8565
# Epoch 79/100
# 856/856 [==============================] - 0s 286us/step - loss: 8.4154e-04 - acc: 0.8621 - val_loss: 8.3645e-04 - val_acc: 0.8500
# Epoch 80/100
# 856/856 [==============================] - 0s 304us/step - loss: 8.2798e-04 - acc: 0.8715 - val_loss: 7.9976e-04 - val_acc: 0.8573
# Epoch 81/100
# 856/856 [==============================] - 0s 314us/step - loss: 8.5078e-04 - acc: 0.8657 - val_loss: 8.5935e-04 - val_acc: 0.8572
# Epoch 82/100
# 856/856 [==============================] - 0s 303us/step - loss: 7.8744e-04 - acc: 0.8855 - val_loss: 7.9053e-04 - val_acc: 0.8494
# Epoch 83/100
# 856/856 [==============================] - 0s 290us/step - loss: 7.9666e-04 - acc: 0.8750 - val_loss: 8.5583e-04 - val_acc: 0.8367
# Epoch 84/100
# 856/856 [==============================] - 0s 300us/step - loss: 8.2419e-04 - acc: 0.8692 - val_loss: 8.5589e-04 - val_acc: 0.8538
# Epoch 85/100
# 856/856 [==============================] - 0s 286us/step - loss: 8.0284e-04 - acc: 0.8773 - val_loss: 8.5718e-04 - val_acc: 0.8506
# Epoch 86/100
# 856/856 [==============================] - 0s 291us/step - loss: 7.8973e-04 - acc: 0.8808 - val_loss: 8.3233e-04 - val_acc: 0.8508
# Epoch 87/100
# 856/856 [==============================] - 0s 292us/step - loss: 7.7519e-04 - acc: 0.8586 - val_loss: 8.8021e-04 - val_acc: 0.8504
# Epoch 88/100
# 856/856 [==============================] - 0s 270us/step - loss: 8.0506e-04 - acc: 0.8715 - val_loss: 9.0129e-04 - val_acc: 0.8462
# Epoch 89/100
# 856/856 [==============================] - 0s 309us/step - loss: 7.9229e-04 - acc: 0.8575 - val_loss: 8.5959e-04 - val_acc: 0.8495
# Epoch 90/100
# 856/856 [==============================] - 0s 286us/step - loss: 7.5571e-04 - acc: 0.8867 - val_loss: 7.8610e-04 - val_acc: 0.8563
# Epoch 91/100
# 856/856 [==============================] - 0s 299us/step - loss: 8.3243e-04 - acc: 0.8633 - val_loss: 8.5821e-04 - val_acc: 0.8510
# Epoch 92/100
# 856/856 [==============================] - 0s 250us/step - loss: 7.7702e-04 - acc: 0.8832 - val_loss: 8.7928e-04 - val_acc: 0.8567
# Epoch 93/100
# 856/856 [==============================] - 0s 284us/step - loss: 8.2099e-04 - acc: 0.8832 - val_loss: 8.6359e-04 - val_acc: 0.8539
# Epoch 94/100
# 856/856 [==============================] - 0s 280us/step - loss: 8.1543e-04 - acc: 0.8797 - val_loss: 7.9229e-04 - val_acc: 0.8524
# Epoch 95/100
# 856/856 [==============================] - 0s 268us/step - loss: 7.4233e-04 - acc: 0.8867 - val_loss: 8.6876e-04 - val_acc: 0.8516
# Epoch 96/100
# 856/856 [==============================] - 0s 298us/step - loss: 7.2872e-04 - acc: 0.8797 - val_loss: 8.3364e-04 - val_acc: 0.8535
# Epoch 97/100
# 856/856 [==============================] - 0s 288us/step - loss: 7.8111e-04 - acc: 0.8773 - val_loss: 8.2432e-04 - val_acc: 0.8556
# Epoch 98/100
# 856/856 [==============================] - 0s 293us/step - loss: 7.6814e-04 - acc: 0.8797 - val_loss: 8.2637e-04 - val_acc: 0.8517
# Epoch 99/100
# 856/856 [==============================] - 0s 299us/step - loss: 7.5666e-04 - acc: 0.8890 - val_loss: 8.1817e-04 - val_acc: 0.8521
# Epoch 100/100
# 856/856 [==============================] - 0s 266us/step - loss: 7.3629e-04 - acc: 0.8773 - val_loss: 8.4834e-04 - val_acc: 0.8495

# %%
# predicting    
# k21_predict = pandas.DataFrame(model.predict(k20_data), columns = k21_features)
k21_predict = model.predict(k20_data)

features_name_20 = [f.replace('_20', '')[::-1] for f in k20_features]
features_name_21 = [f.replace('_21', '')[::-1] for f in k21_features]

ind = numpy.arange(len(features_name_21))
width = 0.4


def plot_me(pos, n):
    plt.subplot(pos)
    plt.barh(ind+width/2, k21_predict[n], width, color='red', label='תיזחת')
    plt.barh(ind-width/2, k21_data.values[n], width, color='blue', label='לעופב')
    plt.yticks(ind, features_name_21)

    location = str(k20_21_merged['שם ישוב'][n])[::-1] 
    ballot = str(int(k20_21_merged['מספר קלפי'][n])) + ' :יפלק'
    accuracy = str(round(cosine_similarity([k21_predict[n]], [k21_data.values[n]])[0][0], 2))
    plt.title( location + '\n' + ballot + '\n' + 'cosine similarity: ' + accuracy)
    plt.legend()

plt.figure(figsize=(15,8))
plot_me(141, numpy.random.randint(0, len(k20_21_merged)))
plot_me(142, numpy.random.randint(0, len(k20_21_merged)))
plot_me(143, numpy.random.randint(0, len(k20_21_merged)))
plot_me(144, numpy.random.randint(0, len(k20_21_merged)))

# %%
# find anomalies
similarities = [cosine_similarity([k21_data.values[idx]], [k21_predict[idx]])[0][0] for idx in range(len(k20_21_merged))] 
worse = (numpy.array(similarities)).argsort()[:4]
plt.figure(figsize=(15,8))
plot_me(141, worse[0])
plot_me(142, worse[1])
plot_me(143, worse[2])
plot_me(144, worse[3])

# %%
def remove_zeros(df, axis):
    zero_idx = numpy.argwhere(df.sum(axis=1-axis).values == 0).flatten()
    labels = df.columns[zero_idx] if axis == 1 else df.index[zero_idx]
    return df.drop(labels, axis=axis)


diag = numpy.diagflat(numpy.ones(k20_len))
diag_predict = pandas.DataFrame(model.predict(diag), columns=features_name_21, index=features_name_20)
diag_predict = remove_zeros(diag_predict, axis=0)
diag_predict = remove_zeros(diag_predict, axis=1)

plt.figure(figsize=(13, 13))
plt.imshow(diag_predict)
plt.xticks(numpy.arange(len(diag_predict.columns)), diag_predict.columns)
plt.xlabel("Knesset 21")

plt.yticks(numpy.arange(len(diag_predict.index)), diag_predict.index)
plt.ylabel("Knesset 20")

# Loop over data dimensions and create text annotations.
for i in range(len(diag_predict.index)):
    for j in range(len(diag_predict.columns)):
        v = diag_predict.values[i, j]*100
        if v > 10:
            text = plt.text(j, i, int(v), ha="center", va="center", color="w")

plt.show()

# %%
dist = numpy.zeros((len(diag_predict.columns), len(diag_predict.columns)))

for i in range(len(dist)):
    max_similarity = 0
    most_similar = 0
    for j in range(len(dist)):
        ii = diag_predict[diag_predict.columns[i]]
        jj = diag_predict[diag_predict.columns[j]]
        dist[i,j] = cosine_similarity([ii], [jj])
        
        if dist[i, j] > max_similarity and i != j:
            max_similarity = dist[i, j]
            most_similar = j

    if max_similarity > 0:
        print (diag_predict.columns[i][::-1], '->', diag_predict.columns[most_similar][::-1], round(max_similarity, 2))

dist = pandas.DataFrame(dist, columns=diag_predict.columns, index=diag_predict.columns)
dist = remove_zeros(dist, 0)
dist = remove_zeros(dist, 1)

plt.figure(figsize=(7, 7))
plt.imshow(dist)
plt.xticks(numpy.arange(len(dist.columns)), dist.columns)
plt.yticks(numpy.arange(len(dist.columns)), dist.columns)
plt.show()
# Out:
# אמת -> פה 0.96
# ג -> שס 0.41
# דעם -> ום 0.74
# ום -> דעם 0.74
# ז -> נ 0.76
# טב -> נ 0.99
# כ -> מחל 0.93
# ל -> ז 0.3
# מחל -> כ 0.93
# מרצ -> אמת 0.75
# נ -> טב 0.99
# פה -> אמת 0.96
# שס -> מחל 0.45

# %%
import networkx as nx
G = nx.Graph()

for i in range(len(dist.columns)):
    for j in range(i, len(dist.columns)):
        G.add_edge(dist.columns[i], dist.columns[j], {'weight': dist.values[i, j]})
        
plt.figure(figsize=(7, 7))
nx.draw_networkx(G, with_labels=True, node_color='lightblue', edge_color='white', font_weight='bold')

# %%
# dist
# projected = IncrementalPCA(n_components=2).fit_transform(diag_predict.T)
# projected.shape

# # projected = TSNE(n_components=2).fit_transform(dist)
# projected = pandas.DataFrame(projected, columns=['x', 'y'])
# projected['party'] = pandas.Series(diag_predict.T.index)

# plt.figure(figsize=(7, 7))
# plt.scatter(projected['x'], projected['y'], color='w')

# # # Loop over data dimensions and create text annotations.
# for i in range(len(diag_predict.T.index)):
#     rec = projected.loc[i]
#     text = plt.text(rec['x'], rec['y'], rec['party'], color='red', fontsize=12)


# plt.show()
